# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#creating the function and plotting it
function = lambda x: (x ** 3)-(3 *(x ** 2))+7
#Get 1000 evenly spaced numbers between -1 and 3 (arbitratil chosen to ensure steep curve)
x = np.linspace(-1,3,500)
#Plot the curve
plt.plot(x, function(x))
plt.show()

# %%
def deriv(x):
    x_deriv = 3* (x**2) - (6 * (x))
    return x_deriv

# %%
def step(x_new, x_prev, precision, l_r):

    '''
     Descrição: Esta função recebe um valor inicial ou anterior para x, atualiza-o com base
     passos tomados através da taxa de aprendizagem e produz o valor mínimo de x que atinge
     Argumentos:
         x_new - um valor inicial de x que será atualizado com base na taxa de aprendiza
         x_prev - o valor anterior de x que está sendo atualizado para o novo
         precisão - uma precisão que determina a parada da descida em etapas
         l_r - a taxa de aprendizado (tamanho de cada etapa de descida)
     Saída:
         1. Imprime o último novo valor de x que equivale ao mínimo que estamos procuran
         2. Imprime o número de valores x que equivale ao número de etapas de descida de
         3. Plota um primeiro gráfico da função com o caminho de descida de gradiente
         4. Plota um segundo gráfico da função com um caminho de descida de gradiente am
     '''

    # create empty lists where the updated values of x and y wil be appended during each it

    x_list, y_list = [x_new], [function(x_new)]

    # keep looping until your desired precision
    while abs(x_new - x_prev) > precision:
        # change the value of x
        x_prev = x_new

        # get the derivation of the old value of x
        d_x = - deriv(x_prev)

        # get your new value of x by adding the previous, the multiplication of the derivat
        x_new = x_prev + (l_r * d_x)

        # append the new value of x to a list of all x-s for later visualization of path
        x_list.append(x_new)

        # append the new value of y to a list of all y-s for later visualization of path
        y_list.append(function(x_new))
        print ("Local minimum occurs at: "+ str(x_new))
        print ("Number of steps: " + str(len(x_list)))


        plt.subplot(1,2,2)
        plt.scatter(x_list,y_list,c="g")
        plt.plot(x_list,y_list,c="g")
        plt.plot(x,function(x), c="r")
        plt.title("Gradient descent")
        plt.show()
        plt.subplot(1,2,1)
        plt.scatter(x_list,y_list,c="g")
        plt.plot(x_list,y_list,c="g")
        plt.plot(x,function(x), c="r")
        plt.xlim([1.0,2.1])
        plt.title("Zoomed in Gradient descent to Key Area")
        plt.show()

# %%
step(0.5, 0, 0.001, 0.05)
# Out:
# Local minimum occurs at: 0.6125
# Number of steps: 2
# Local minimum occurs at: 0.7399765625000001
# Number of steps: 3
# Local minimum occurs at: 0.8798347342926027
# Number of steps: 4
# Local minimum occurs at: 1.0276687806302234
# Number of steps: 5
# Local minimum occurs at: 1.1775539464169889
# Number of steps: 6
# Local minimum occurs at: 1.3228251358337517
# Number of steps: 7
# Local minimum occurs at: 1.4571927255848396
# Number of steps: 8
# Local minimum occurs at: 1.5758389473356855
# Number of steps: 9
# Local minimum occurs at: 1.676100373345385
# Number of steps: 10
# Local minimum occurs at: 1.7575336161197197
# Number of steps: 11
# Local minimum occurs at: 1.8214550391870068
# Number of steps: 12
# Local minimum occurs at: 1.8702367819761478
# Number of steps: 13
# Local minimum occurs at: 1.9066399734705175
# Number of steps: 14
# Local minimum occurs at: 1.9333405672463244
# Number of steps: 15
# Local minimum occurs at: 1.952671875076171
# Number of steps: 16
# ...
